# %%
def zero(a=None):
    if (not a):
        return 0
    else:
        return a(0) #your code here
def one(a=None):
    if (not a):
        return 1
    else:
        return a(1)  #your code here
def two(a=None):
    if (not a):
        return 2
    else:
        return a(2) #your code here
def three(a=None):
    if (not a):
        return 3
    else:
        return a(3) #your code here
def four(a=None):
    if (not a):
        return 4
    else:
        return a(4) #your code here
def five(a=None):
    if (not a):
        return 5
    else:
        return a(5) #your code here
def six(a=None): 
    if (not a):
        return 6
    else:
        return a(6) #your code here
def seven(a=None):
    if (not a):
        return 7
    else:
        return a(7) #your code here
def eight(a=None):
    if (not a):
        return 8
    else:
        return a(8) #your code here
def nine(a=None):
    if (not a):
        return 9
    else:
        return a(9)#your code here

def plus(j):
    return lambda i: i+j
def minus(j):
    return lambda i:i-j
def times(j):
    return lambda i:i*j 
def divided_by(j):
    return lambda i:i//j
